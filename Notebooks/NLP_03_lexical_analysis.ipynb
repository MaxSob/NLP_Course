# %% [markdown]
# # NLP Lexical analysis

# %% [markdown]
# The lexical analysis in NLP deals with the study at the level of words with respect to their lexical meaning and part-of-speech. This level of linguistic processing utilizes a language’s lexicon, which is a collection of individual lexemes. A lexeme is a basic unit of lexical meaning; which is an abstract unit of morphological analysis that represents the set of forms or “senses” taken by a single morpheme.

# %% [markdown]
# ## Lexicon
# A lexicon, or lexical resource, is a collection of words and/or phrases along with associated information, such as part-of-speech and sense definitions. Lexical resources are secondary to texts, and are usually created and enriched with the help of texts.

# %%
import nltk
wordlist = nltk.corpus.words.words()
print(len(wordlist))
[w for w in wordlist if len(w) >= 23]
# Out:
# 236736
# ['anthropomorphologically',
#  'blepharosphincterectomy',
#  'epididymodeferentectomy',
#  'formaldehydesulphoxylate',
#  'formaldehydesulphoxylic',
#  'gastroenteroanastomosis',
#  'hematospectrophotometer',
#  'macracanthrorhynchiasis',
#  'pancreaticoduodenostomy',
#  'pathologicohistological',
#  'pathologicopsychological',
#  'pericardiomediastinitis',
#  'phenolsulphonephthalein',
#  'philosophicotheological',
#  'Pseudolamellibranchiata',
#  'pseudolamellibranchiate',
#  'scientificogeographical',
#  'scientificophilosophical',
#  'tetraiodophenolphthalein',
#  'thymolsulphonephthalein',
#  'thyroparathyroidectomize',
#  'transubstantiationalist']

# %% [markdown]
# Let's start to build our lexicon from our tweets database

# %%
import os
import pandas as pd
os.listdir()
# Out:
# ['NLP_03_lexical_analysis.ipynb',
#  'NLP_04_syntactic_analysis.ipynb',
#  '__pycache__',
#  'SimplePushdownAutomata',
#  'Teacher',
#  'NLP_05_semantic_analysis.ipynb',
#  'NLP_02_preprocessing.ipynb',
#  'NLP_01_intro.ipynb',
#  'resources',
#  '.ipynb_checkpoints']

# %%
dir_data = "../data/"
df = pd.read_csv(dir_data + 'finalizedtest.csv')
df.describe()
# Out:
#             senti
# count  298.000000
# mean     2.006711
# std      1.748483
# min      0.000000
# 25%      0.000000
# 50%      2.000000
# 75%      4.000000
# max      4.000000

# %%
df.head()
# Out:
#                                                tweet  senti
# 0  @united Oh, we are sure it's not planned, but ...      0
# 1                          History exam studying ugh      0
# 2  @unnitallman yeah looks like that only! &quot;...      0
# 3                                      Loves twitter      4
# 4  @Mbjthegreat i really dont want AT&amp;T phone...      0

# %%
tweets_lexicon = {}
tokenizer = nltk.tokenize.TweetTokenizer()
for t in df["tweet"]:
    print(t)
    tokens = tokenizer.tokenize(t)
# Out:
# @united Oh, we are sure it's not planned, but it occurs absolutely consistently, it's usually the only YYJ flight that's Cancelled Flightled daily.
# History exam studying ugh
# @unnitallman yeah looks like that only! &quot;busy&quot; is fucking me so yeah.. its my &quot;GF&quot;
# Loves twitter
# @Mbjthegreat i really dont want AT&amp;T phone service..they suck when it comes to having a signal
# I donâ€™t want either! RT @clayhebert: We might get pilotless planes before driverless cars - http://t.co/y4YOxaqI
# Super cool: "@google: The next stop on the road to a self-driving car http://t.co/x4rem8zeKy http://t.co/UPdUUaTTb6"
# Aw fuck - this night ended badly
# Ok so lots of buzz from IO2009 but how lucky are they - a Free G2!! http://is.gd/Hyzl
# @mrskutcher it's only 1am here...i'm just on my way TO bed lol. weird. hope you have a good morning!
# Driverless cars seem way overhyped given the infrastructure challenges, pilotless planes seem much more doable and needed.
# How to Track Iran with Social Media: http://bit.ly/2BoqU
# Google's self-driving car still has many flaws http://t.co/qgqe2JoYMD via @sharethis @google #Autonomous  #Robots
# Can't wait for driverless cars to come out! This is the first time I'm excited about motor vehicles, in my entire life.
# @Vonster good point, 2 draw  2 don't  nice quote though. I like that.
# Time Warner Road Runner customer support here absolutely blows. I hate not having other high-speed net options. I'm ready to go nuclear.
# @barrier_trio i like to piss ppl off by comparing things like Google Car to robber barons throwing silver dollars from their office windows
# I told  that I think I was getting sick and he goes "I'll give you some of that Claritin D!" #eww
# The Nike Training Club (beta) iPhone app looks very interesting.
# HATE safeway select green tea icecream! bought two cartons, what a waste of money.  &gt;_&lt;
#  #AAPL was a fantastic investment...but what will be its future?  How will AAPL beat AAPL?
# 's CEO battles to appease passengers and Wall Street - Waterbury Republican American /IMVMpnQXAI
# Judd Apatow creates fake sitcom on NBC.com to market his new movie... viral marketing at its best. http://is.gd/K0yK
# time warner really picks the worst time to not work. all i want to do is get to mtv.com so i can watch the hills. wtfffff.
# @mayhemstudios Yes, using it for 3 week now. Pretty happy with the result
# Tomorrow is my friday!  +it's a late day for me. Thank goodness.
# @united better just keep connection from ORD To FWA that boards in ten minutes open until I get off the plane that just landed an hour Late Flight
# eating cake
# @hassox no, but that sounds like a good idea, steve.
# Are YOU burning more cash $$$ than Chrysler and GM? Stop the financial tsunami. Where "bailout" means taking a handout!
# Going to see star trek soon with my dad.
# Safari 4 is fast :) Even on my shitty AT&amp;T tethering.
# @united Flew ORD to Miami and back and  had great crew, service on both legs. THANKS
# Man im too fucked to be in work
# @beycah Good for you Becca, have a good sleep.
# giving weka an app engine interface, using the bird strike data for the tests, the logo is a given.
# Life?s a bitch? and so is Dick Cheney. #p2 #bipart #tlot #tcot #hhrs #GOP #DNC http://is.gd/DjyQ
# â€œ: A self-driving car? Here's one you can (not) drive today: /SIHOcdE5mE
# yahoo answers can be a butt sometimes
# : Be honest--only real surprise about #DeflateGate is that ARod isn't somehow involved.
# North Korea, please cease this douchebaggery. China doesn't even like you anymore. http://bit.ly/NeHSl
# I want a driverless car so bad.
# 8:28 AM - The driverless cars take us to the wrong spot. @DustyEyesSEM says, "Damn Robots." I agree. We board a bus. #DelucchiDoesGoogle
# @nick_carter you are my IDOL, i love you!  you should reply to me.. &lt;3
# my dentist was wrong... WRONG
# @evelynbyrne have you tried Nike  ? V. addictive.
# BaseballAmerica.com: Blog: Baseball America Prospects Blog ? Blog ... http://bit.ly/EtT8a
# It's got to be nice to be Ted Wells. There's steady work when you're the #NFL's go to guy for investigations.
#
# #DeflateGate
# Should nott be up this early  fuckk me
# Going to the dentist later.:|
# @erickoston That looks an awful lot like one of Nike's private jets....I'm just sayin....
# â€œ:   I thought it was a self-driving car?!?!â€&lt; must be a manual override by a "Type A"
# Watching a programme about the life of Hitler, its only enhancing my geekiness of history.
# @Cookcj I love reading your tweets but it would be nice to see your lovely mug when I read them. Where's your picture?
# Driverless cars!?!?!?!?, I don't think so!! What about all of the rest of crazed &amp; drunk drivers on the road in our society today !??ðŸ™âœŒï¸ðŸŒŽðŸ’«ðŸ‡ºðŸ‡¸
# saw night at the museum out of sheer desperation. who is funding these movies?
# Warren Buffet on the economy http://ping.fm/Lau0p
# @united Thanks, ^KP. Please also mention the Quiche breakfast and Tandoori chicken dinner entrees and accompaniments are truly First Class.
# #Durham Driverless car causes crash in NC, two people injured - http://t.co/Oz48xG2bX4 http://t.co/sgdLDH1PJF #dur @DurhamNC_
# Awesome viral marketing for "Funny People" http://www.nbc.com/yo-teach/
# Lounging around, eating Taco Bell and watching NCIS before work tonight. Need help staying awake.
# My wrist still hurts. I have to get it looked at. I HATE the dr/dentist/scary places. :( Time to watch Eagle eye. If you want to join, txt!
# The ever amazing Psyop and Goodby Silverstein &amp; Partners for HP! http://bit.ly/g2rU8 Have to go play with After Effects now!
# Absolutely hilarious!!! from @mashable:  http://bit.ly/bccWt
#  and I just saw the google car!  /vkougcNg
# fuck. Lidelle is my favorite
# Ahh...got rid of stupid time warner today &amp; now taking a nap while the roomies cook for me. Pretty good end for a monday :)
# Lakers played great!  Cannot wait for Thursday night Lakers vs. ???
# @legalgeekery Yeahhhhhhhhh, I wouldn't really have lived in East Palo Alto if I could have avoided it.  I guess it's only for the summer.
# Time Warner cable phone reps r dumber than nails!!!!! UGH! Cable was working 10 mins ago now its not WTF!
# And so a down day on the market...happy my stocks held up
# @JonathanRKnight Hi Jon! Great to hear from you! See you on the cruise, I cannot wait! Hope all is well on the Knight bus!  You are loved!
# Sony coupon code.. Expires soon.. http://www.coupondork.com/r/1796
# Nike owns NBA Playoffs ads w/ LeBron, Kobe, Carmelo? http://ow.ly/7Uiy  #Adidas #Billups #Howard  #Marketing #Branding
# It is a shame about GM. What if they are forced to make only cars the White House THINKS will sell? What do you think?
# with the boyfriend, eating a quesadilla
# Shit's hitting the fan in Iran...craziness indeed #iranelection
# So fucking sick. No worries, chug on m'son! You have things to do and places to be...
# My dad was in NY for a day, we ate at MESA grill last night and met Bobby Flay. So much fun, except I completely lost my voice today.
# @criticalpath Such an awesome idea - the  continual learning program with a Kindle2  http://bit.ly/1ZLfF
# Talk is Cheap: Bing that, I?ll stick with Google. http://bit.ly/XC3C8
# @CTesdahl well you can always digg or stumble...both have aided me greatly in wasting countless hours of my life
# Stopped to have lunch at McDonalds. Chicken Nuggetssss! :) yummmmmy.
# SUPER INVESTORS: A great weekend read here from Warren Buffet. Oldie, but a goodie. http://tinyurl.com/oqxgga

# %% [markdown]
# **Exercise:** Build a minimal lexicon holding each word in the tweets sentiment analysis database. Associate each word with the number of times it appears on the text. Perform a simple preprocessing using noise removal, and case normlaization

# %%
def cleanString(special_chars, string):
    cleansed_string = string
    #Your code here
    for char in special_chars:
        cleansed_string = cleansed_string.replace(char, '')
    return clenased_string

tokenizer = nltk.tokenize.TweetTokenizer()
# [('.', 228), ('the', 118), ('!', 118), (',', 99), ('to', 96), ('I', 86), ('a', 77), ('and', 64), ('?', 62), ('is', 53), ('my', 48), ('for', 46), (':', 44), ('in', 40), ('on', 38), ('you', 38), ('of', 35), ('...', 32), ('"', 30), ('that', 29), ('-', 29), ('it', 28), ('me', 27), ('good', 26), ('car', 25), ('@united', 24), ('be', 24), ('was', 24), ('with', 23), ('have', 22), ('cars', 21), ('at', 21), ('just', 21), ('/', 20), ('from', 19), ('are', 18), ('i', 17), ('this', 17), ('by', 17), ("'", 16), ('so', 15), ("I'm", 15), ('about', 15), ('not', 14), ('like', 14), ('(', 14), (')', 14), ('your', 14), ('fucking', 13), ('..', 13), ('&', 13), ('€', 13), ('got', 13), ('up', 13), ('Google', 13), ('love', 13), ('2', 13), ('go', 13), ('but', 12), ('now', 12), ('driverless', 11), ('The', 11), ('self-driving', 11), ('day', 11), ('we', 10), ('an', 10), ('out', 10), (':)', 10), ('can', 10), ('will', 10), ('him', 10), ('$', 10), ("it's", 9), ('only', 9), ('fuck', 9), ('night', 9), ('new', 9), ('great', 9), ('has', 9), ('today', 9), ('Nike', 9), ('more', 9), ('GM', 9), ('really', 8), ('get', 8), ('here', 8), ('Night', 8), ('Museum', 8), ('one', 8), ('do', 8), ('â', 8), ('Time', 8), ('all', 8), ('work', 8), ('way', 7), ('google', 7), ('<3', 7), ('time', 7), ('Twitter', 7), ('his', 7), ('if', 7), ('Driverless', 7), ('Just', 7), ("that's", 6), ('its', 6), ('want', 6), ('service', 6), ('they', 6), ('when', 6), ('been', 6), ('self', 6), ('driving', 6), ('could', 6), ('œ', 6), ('Kindle', 6), ('over', 6), ('Warner', 6), ('or', 6), ('My', 6), ('back', 6), ('wait', 6), ('people', 6), ('off', 6), ('saw', 6), ('see', 6), ("It's", 6), (':(', 6), ('some', 6), ('eating', 6), ('after', 6), ('still', 6), ('think', 6), ('Oh', 5), ('flight', 5), ('dentist', 5), ('week', 5), ('happy', 5), ('why', 5), ('had', 5), ('#DeflateGate', 5), ('trip', 5), ('home', 5), ('China', 5), ('What', 5), ('How', 5), ('So', 5), ('using', 5), ('much', 5), ('than', 5), ('fucked', 5), ('am', 5), ('hours', 5), ('totally', 5), ('amazing', 5), ('look', 5), ('Thanks', 5), ('lol', 5), ('life', 5), ('*', 5), ("don't", 5), ('phone', 4), ('RT', 4), ('We', 4), ('before', 4), ('doing', 4), ('there', 4), ('money', 4), ("Google's", 4), ('They', 4), ('w', 4), ('No', 4), ('around', 4), ('already', 4), ('New', 4), ('wish', 4), ('And', 4), ('know', 4), ('thanks', 4), ('them', 4), ('read', 4), ('s', 4), ('well', 4), ('past', 4), ('guy', 4), ('tonight', 4), ('feel', 4), ('hate', 4), ('Car', 4), ('1', 4), ('API', 4), ('nice', 4), ('last', 4), ('\x9d', 4), ('two', 4), ('If', 4), ('u', 4), ('help', 4), ('watch', 4), ('+', 4), ('A', 4), ('would', 4), ('Blog', 4), ('exam', 3), ('ugh', 3), ('looks', 3), ('AT', 3), ('T', 3), ('having', 3), ('planes', 3), ('cool', 3), ('next', 3), ('road', 3), ('how', 3), ('G2', 3), ("you're", 3), ('better', 3), ("I've", 3), ('though', 3), ('even', 3), ('made', 3), ('into', 3), ('give', 3), ('us', 3), ('Back', 3), ('something', 3), ('hour', 3), ('entire', 3), ('lost', 3), ('Get', 3), ('card', 3), ('post', 3), ('blog', 3), ('morning', 3), ('should', 3), ('feed', 3), ('did', 3), ('find', 3), ('no', 3), ('warner', 3), ('Watching', 3), ('Damn', 3), ('as', 3), ('Love', 3), ('stupid', 3), ('going', 3), ('safeway', 3), ('hear', 3), ('You', 3), ('hope', 3), ('many', 3), ('best', 3), ("I'd", 3), ('excited', 3), ('she', 3), ('insects', 3), ('Obama', 3), ('Than', 3), ('high', 3), ('North', 3), ('flights', 3), ('taking', 3), ('@mashable', 3), ('Now', 3), ('ðŸ', 3), ('who', 3), ('drive', 3), ('our', 3), ('Hi', 3), ('getting', 3), ('their', 3), ('being', 3), ("won't", 3), ('what', 3), ('support', 3), ('Star', 3), ('Trek', 3), ('>', 3), ('also', 3), ('American', 3), ('giving', 3), ('thought', 3), ('via', 3), ('bed', 3), ('Pretty', 3), ('tweets', 3), ('ever', 3), ('these', 3), ('absolutely', 2), ('Cancelled', 2), ('Flightled', 2), ('yeah', 2), ('GF', 2), ('suck', 2), ('™', 2), ('pilotless', 2), ('Super', 2), ('@google', 2), ('later', 2), ('Flight', 2), ('D', 2), ('C', 2), ('Learning', 2), ('Bo ...

# %% [markdown]
# ## Part of Speech Tagging
# In corpus linguistics, part-of-speech tagging (POS tagging or PoS tagging or POST), also called grammatical tagging or word-category disambiguation, is the process of marking up a word in a text (corpus) as corresponding to a particular part of speech, based on both its definition and its context — i.e., its relationship with adjacent and related words in a phrase, sentence, or paragraph. A simplified form of this is commonly taught to school-age children, in the identification of words as nouns, verbs, adjectives, adverbs, etc.

# %% [markdown]
# Let's build a simple POS tagger using the tweet corpus and the tags offered by nltk POS tagger

# %%
import nltk

text = nltk.word_tokenize("They refuse to permit us to obtain the refuse permit")
nltk.pos_tag(text)
# Out:
# [('They', 'PRP'),
#  ('refuse', 'VBP'),
#  ('to', 'TO'),
#  ('permit', 'VB'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('obtain', 'VB'),
#  ('the', 'DT'),
#  ('refuse', 'NN'),
#  ('permit', 'NN')]

# %% [markdown]
# ## Updating the lexicon

# %% [markdown]
# Let's update the lexicon to consider the tags, assigned to a token and the next tag seen

# %% [markdown]
# **Exercise**
# Remove stopwords from our previous lexicon
#
# Hint: cehck python implementations of the nltk corpus stopwords

# %%
from nltk.corpus import stopwords
sw = set(stopwords.words('english'))
sws = set(stopwords.words('spanish'))
print(sw)
# Out:
# {'each', 'y', 'from', 'any', 'so', 've', 'is', 'them', 'don', 'ain', 'the', 'his', "mustn't", 'doesn', 'who', 'my', 'of', 'under', 'our', 'you', 'at', 'it', "hasn't", 'have', 'being', 'before', 'only', 'd', 'as', 'm', 'me', 'ours', 'too', 'these', 'what', 'and', 'themselves', 'hasn', 'needn', 'because', 'has', 'hadn', 'why', 'weren', 'herself', 'theirs', 'most', 'aren', 'been', 'itself', 'against', "that'll", 'when', 'for', 'him', 'mustn', 'hers', 'than', 'shouldn', 'an', 'we', 'all', 'couldn', 'doing', "wouldn't", "didn't", "you're", 'that', 're', 'isn', "you'd", 'down', 'she', 'ourselves', 'after', "shan't", "you'll", 'just', 'll', 'while', 'himself', 'will', 'below', 'if', "haven't", 'whom', "don't", 'they', 'was', 'were', 'during', 'both', 'same', 't', 'your', 'did', 'be', 'can', 'yourself', 'by', 'again', 'shan', 'wasn', 'having', "shouldn't", 'to', 'o', "aren't", 'there', 'with', 'more', 'i', 'but', 'over', 'wouldn', 'about', 'ma', "needn't", 'yours', 'off', 'very', 'here', 'further', "mightn't", 'myself', 'her', 'this', 's', 'yourselves', 'where', "it's", "couldn't", "should've", "hadn't", "isn't", 'do', 'up', 'through', "won't", "weren't", "you've", 'other', 'won', 'its', 'nor', 'didn', 'those', 'or', 'own', 'he', 'on', 'should', 'until', 'does', "she's", 'am', 'some', 'which', 'in', 'not', 'once', 'no', "wasn't", 'few', 'out', 'into', 'above', 'had', 'such', 'mightn', 'are', 'haven', 'how', 'then', 'a', 'between', "doesn't", 'now', 'their'}

# %%
#print(tweet_lexicon)
d_keys = list(tweet_lexicon.keys())
print(str(len(d_keys)) + " words in the dictionary")
deleted = 0
for i in d_keys:
    if i in sw and i in tweet_lexicon:
        deleted += 1
        del tweet_lexicon[i]
print("Deleted " + str(deleted) + " stopwords")
print(tweet_lexicon)
# Out:
# 1823 words in the dictionary
# Deleted 0 stopwords
# {'@united': 24, 'Oh': 5, ',': 99, 'sure': 1, 'planned': 1, 'occurs': 1, 'absolutely': 2, 'consistently': 1, 'usually': 1, 'YYJ': 1, 'flight': 5, "that's": 6, 'Cancelled': 2, 'Flightled': 2, 'daily': 1, '.': 228, 'History': 1, 'exam': 3, 'studying': 1, 'ugh': 3, '@unnitallman': 1, 'yeah': 2, 'looks': 3, 'like': 14, '!': 118, '"': 30, 'busy': 1, 'fucking': 13, '..': 13, 'GF': 2, 'Loves': 1, 'twitter': 1, '@Mbjthegreat': 1, 'really': 8, 'dont': 1, 'want': 6, 'AT': 3, '&': 13, 'T': 3, 'phone': 4, 'service': 6, 'suck': 2, 'comes': 1, 'signal': 1, 'I': 86, 'donâ': 1, '€': 13, '™': 2, 'either': 1, 'RT': 4, '@clayhebert': 1, ':': 44, 'We': 4, 'might': 1, 'get': 8, 'pilotless': 2, 'planes': 3, 'driverless': 11, 'cars': 21, '-': 29, 'http://t.co/y4YOxaqI': 1, 'Super': 2, 'cool': 3, '@google': 2, 'The': 11, 'next': 3, 'stop': 1, 'road': 3, 'self-driving': 11, 'car': 25, 'http://t.co/x4rem8zeKy': 1, 'http://t.co/UPdUUaTTb6': 1, 'Aw': 1, 'fuck': 9, 'night': 9, 'ended': 1, 'badly': 1, 'Ok': 1, 'lots': 1, 'buzz': 1, 'IO2009': 1, 'lucky': 1, 'Free': 1, 'G2': 3, 'http://is.gd/Hyzl': 1, 'got': 13, 'new': 9, 'pair': 1, 'nike': 1, 'shoes': 1, 'pics': 1, 'later': 2, 'Hey': 1, 'chance': 1, 'update': 1, 'Flight': 2, '99': 1, 'Hartford': 1, 'D': 2, 'C': 2, '?': 62, 'Learning': 2, 'jQuery': 1, '1.3': 1, 'Book': 2, 'Review': 1, 'http://cfbloggers.org/?c=30629': 1, '@kirstiealley': 2, 'dentist': 5, 'great': 9, 'expensive': 2, '...': 32, '=
# %% [markdown]
# **Exercise** Update the lexicon to include the generated tags for each tweet at the moment of tokenization and for the next word,
#
# Hint: perform sotpword removal

# %%
new_tweet_lexicon = {}
tokenizer = nltk.tokenize.TweetTokenizer()
for t in df["tweet"]:
    #Remove Noise
    #Lower case
    #Tokenize
    #Stop word removal
    #Get tags and append it to a list
    #Get next tokens tag and append it to a list
    
print(new_tweet_lexicon)
for e in new_tweet_lexicon.keys():
    data = new_tweet_lexicon[e]
    print(e)
    print(data['ocurrences'])
    print(len(data['tags']))
    print(len(data['next_tags']))
# Out:
#   File "<ipython-input-1-e41a7e9f3e15>", line 11
#     print(new_tweet_lexicon)
#         ^
# IndentationError: expected an indented block

# %% [markdown]
# **Exercise** assgin probabilities of tags using the observed tags of the corpus and it's transitions, count each tag and divide it by the number of ocurrences of the word, ane xample of the calculations is below

# %%
print(new_tweet_lexicon['united'])
# Out:
# {'ocurrences': 27, 'tags': ['JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ', 'VBD', 'JJ', 'JJ', 'JJ', 'JJ', 'JJ'], 'next_tags': ['JJ', 'NN', 'CD', 'VBP', 'NNS', 'NN', 'NNS', 'VBD', 'NN', 'NN', 'NNS', 'NN', 'NN', 'NN', 'NN', 'VBD', 'VBN', 'NN', 'NN', 'NNP', 'NN', 'CD', 'NN', 'VBG', 'JJR', 'VBD', 'NNS']}

# %%
results = {'ocurrences': 27, 'tags': {'JJ': {'ocurrences': 26, 'probability': 0.9629629629629629}, 'VBD': {'ocurrences': 1, 'probability': 0.037037037037037035}}, 'next_tags': {'JJ': {'ocurrences': 1, 'probability': 0.037037037037037035}, 'NN': {'ocurrences': 12, 'probability': 0.4444444444444444}, 'CD': {'ocurrences': 2, 'probability': 0.07407407407407407}, 'VBP': {'ocurrences': 1, 'probability': 0.037037037037037035}, 'NNS': {'ocurrences': 4, 'probability': 0.14814814814814814}, 'VBD': {'ocurrences': 3, 'probability': 0.1111111111111111}, 'VBN': {'ocurrences': 1, 'probability': 0.037037037037037035}, 'NNP': {'ocurrences': 1, 'probability': 0.037037037037037035}, 'VBG': {'ocurrences': 1, 'probability': 0.037037037037037035}, 'JJR': {'ocurrences': 1, 'probability': 0.037037037037037035}}}
print(results)
# Out:
# {'ocurrences': 27, 'tags': {'JJ': {'ocurrences': 26, 'probability': 0.9629629629629629}, 'VBD': {'ocurrences': 1, 'probability': 0.037037037037037035}}, 'next_tags': {'JJ': {'ocurrences': 1, 'probability': 0.037037037037037035}, 'NN': {'ocurrences': 12, 'probability': 0.4444444444444444}, 'CD': {'ocurrences': 2, 'probability': 0.07407407407407407}, 'VBP': {'ocurrences': 1, 'probability': 0.037037037037037035}, 'NNS': {'ocurrences': 4, 'probability': 0.14814814814814814}, 'VBD': {'ocurrences': 3, 'probability': 0.1111111111111111}, 'VBN': {'ocurrences': 1, 'probability': 0.037037037037037035}, 'NNP': {'ocurrences': 1, 'probability': 0.037037037037037035}, 'VBG': {'ocurrences': 1, 'probability': 0.037037037037037035}, 'JJR': {'ocurrences': 1, 'probability': 0.037037037037037035}}}

# %%
def countTags(list_tags):
    #count the tags in the list for
    #seen tags and previous tags
    
print(new_tweet_lexicon)
# Out:
#   File "<ipython-input-2-808218c5415c>", line 5
#     print(new_tweet_lexicon)
#         ^
# IndentationError: expected an indented block

# %%
print(new_tweet_lexicon['united'])
# Out:
# {'ocurrences': 27, 'tags': {'JJ': {'ocurrences': 26, 'probability': 0.9629629629629629}, 'VBD': {'ocurrences': 1, 'probability': 0.037037037037037035}}, 'next_tags': {'JJ': {'ocurrences': 1, 'probability': 0.037037037037037035}, 'NN': {'ocurrences': 12, 'probability': 0.4444444444444444}, 'CD': {'ocurrences': 2, 'probability': 0.07407407407407407}, 'VBP': {'ocurrences': 1, 'probability': 0.037037037037037035}, 'NNS': {'ocurrences': 4, 'probability': 0.14814814814814814}, 'VBD': {'ocurrences': 3, 'probability': 0.1111111111111111}, 'VBN': {'ocurrences': 1, 'probability': 0.037037037037037035}, 'NNP': {'ocurrences': 1, 'probability': 0.037037037037037035}, 'VBG': {'ocurrences': 1, 'probability': 0.037037037037037035}, 'JJR': {'ocurrences': 1, 'probability': 0.037037037037037035}}}

# %% [markdown]
# Let's save our lexicon in a pickle file:

# %%
import pickle
path = "../../data/"
lexicon_file = open(path + 'tweet_lexicon.pickle','wb') 
pickle.dump(new_tweet_lexicon, lexicon_file)

# %% [markdown]
# Detect ambiguous entries

# %%
#Ambiguous entries
ambiguous = []
determined = []
for word in new_tweet_lexicon.keys():
    entry = new_tweet_lexicon[word]
    tags = ",".join(entry['tags'].keys())
    if len(entry['tags'].keys()) > 1:
        print(word + " is ambiguous Can be " + tags)
        ambiguous.append(word)
    else:
        print(word + " is determined. Can be " + tags)
        determined.append(word)
# Out:
# united is ambiguous Can be JJ,VBD
# oh is ambiguous Can be JJ,RB,UH
# sure is determined. Can be NN
# planned is determined. Can be VBN
# occurs is determined. Can be VBZ
# absolutely is determined. Can be RB
# consistently is determined. Can be RB
# usually is determined. Can be RB
# yyj is determined. Can be JJ
# flight is determined. Can be NN
# thats is determined. Can be NNS
# cancelled is determined. Can be VBD
# flightled is ambiguous Can be JJ,VBD
# history is determined. Can be NN
# exam is ambiguous Can be NN,VBP
# studying is determined. Can be VBG
# unnitallman is determined. Can be JJ
# yeah is ambiguous Can be UH,RB,NN
# looks is determined. Can be VBZ
# like is ambiguous Can be IN,VB
# " is ambiguous Can be NNP,JJ,NN,VBP
# busy is determined. Can be JJ
# fucking is ambiguous Can be VBG,NN
# gf is determined. Can be NN
# loves is determined. Can be NNS
# mbjthegreat is determined. Can be NN
# really is determined. Can be RB
# dont is ambiguous Can be JJ,NN,VB
# want is ambiguous Can be VBP,VB
# & is determined. Can be CC
# phone is determined. Can be NN
# servicethey is determined. Can be NN
# suck is determined. Can be VBD
# comes is determined. Can be VBZ
# either is determined. Can be DT
# rt is ambiguous Can be NN,JJ
# clayhebert is determined. Can be NN
# : is determined. Can be :
# might is determined. Can be MD
# get is ambiguous Can be VB,NN,VBP
# pilotless is determined. Can be JJ
# planes is determined. Can be NNS
# driverless is ambiguous Can be NN,JJ,VBP
# cars is determined. Can be NNS
# super is determined. Can be JJ
# cool is ambiguous Can be NN,JJ
# google is ambiguous Can be NN,VBP,NNS,JJ
# next is determined. Can be JJ
# stop is ambiguous Can be NN,VB
# road is determined. Can be NN
# selfdriving is ambiguous Can be VBG,NN
# car is determined. Can be NN
# http://tco/x4rem8zeky is determined. Can be NN
# http://tco/upduuattb6 is determined. Can be NN
# aw is determined. Can be JJ
# fuck is ambiguous Can be JJ,VBD,NN,VBP
# night is determined. Can be NN
# ended is determined. Can be VBN
# ok is determined. Can be JJ
# lots is determined. Can be NNS
# buzz is determined. Can be VBP
# io2009 is determined. Can be JJ
# lucky is determined. Can be JJ
# free is determined. Can be JJ
# g2 is determined. Can be NN
# got is ambiguous Can be VBD,VBN
# new is determined. Can be JJ
# pair is determined. Can be NN
# nike is ambiguous Can be NN,IN,JJ,RB
# shoes is determined. Can be NNS
# pics is determined. Can be NNS
# hey is ambiguous Can be NN,NNS
# chance is determined. Can be NN
# update is determined. Can be JJ
# 99 is determined. Can be CD
# hartford is determined. Can be NN
# learning is ambiguous Can be VBG,JJ
# jquery is determined. Can be NN
# 13 is determined. Can be CD
# book is determined. Can be NN
# review is determined. Can be NN
# kirstiealley is ambiguous Can be JJ,NN
# dentist is determined. Can be NN
# great is determined. Can be JJ
# shes is determined. Can be NNS
# chocolate is determined. Can be VBP
# milk is determined. Can be NN
# bittenbybooks is determined. Can be NNS
# good is determined. Can be JJ
# im is ambiguous Can be NN,CC,JJ,RB,VBP
# glad is ambiguous Can be JJ,NN
# youre is determined. Can be NN
# feeling is determined. Can be VBG
# better is ambiguous Can be RBR,JJR
# ive is determined. Can be JJ
# itll is determined. Can be NN
# crazy is determined. Can be JJ
# week is determined. Can be NN
# though is determined. Can be IN
# apples is determined. Can be NNS
# even is determined. Can be RB
# barely is determined. Can be RB
# anything is determined. Can be NN
# couple is determined. Can be JJ
# features is determined. Can be NNS
# self is ambiguous Can be PRP,NN
# driving is determined. Can be VBG
# glass is determined. Can be NN
# tango is determined. Can be NN
# project is determined. Can be NN
# sophieveronica is determined. Can be NN
# today is determined. Can be NN
# rad is determined. Can be VBP
# made is ambiguous Can be VBN,VBD
# finals is determined. Can be NNS
# cross is ambiguous Can be JJ,NN
# country is determined. Can be NN
# yay is determined. Can be NNS
# love is ambiguous Can be VBP,VB,NN,IN
# sophie is determined. Can be NN
# <3 is ambiguous Can be NNP,NN,RB
# l is determined. Can be NN
# ps is determined. Can be NN
# everythins is determined. Can be VBZ
# museum is determined. Can be NN
# wolverine is determined. Can be VBP
# junk is determined. Can be NN
# food is determined. Can be NN
# perfect is ambiguous Can be NN,JJ
# say is ambiguous Can be VB,VBP
# cut is determined. Can be VBN
# small is determined. Can be JJ
# talk is determined. Can be NN
# ts is ambiguous Can be VB,JJ
# slogan is determined. Can be NNS
# f__k is determined. Can be NN
# give is ambiguous Can be VBP,VB
# us is determined. Can be PRP
# money is determined. Can be NN
# apologies is determined. Can be NNS
# bob is determined. Can be VBP
# sfoyyj is determined. Can be NN
# fight is determined. Can be NN
# several is determined. Can be JJ
# times is determined. Can be NNS
# back is ambiguous Can be RB,JJ
# worked is determined. Can be VBN
# one is determined. Can be CD
# fav is determined. Can be NN
# word is determined. Can be NN
# #deflategate is ambiguous Can be NN,NNP
# #ballghazi is determined. Can be JJ
# #ballgate is determined. Can be NNP
# tom is determined. Can be NN
# brady is determined. Can be JJ
# belichick is ambiguous Can be NNS,VBP
# long is determined. Can be JJ
# time is determined. Can be NN
# democrats is determined. Can be NNS
# base is determined. Can be VBP
# could is determined. Can be MD
# timewarner is determined. Can be VB
# cable is determined. Can be NN
# œfacespics is determined. Can be NNS
# googles is determined. Can be NNS
# http://tco/qymxdtw1d9 is determined. Can be NN
# watched is determined. Can be VBD
# something is determined. Can be NN
# earlier is determined. Can be RBR
# holy is ambiguous Can be JJ,NN
# 175 is determined. Can be CD
# hour is determined. Can be NN
# delay is determined. Can be NN
# nothing is determined. Can be NN
# says is determined. Can be VBZ
# sorry is ambiguous Can be VBP,NN
# voucher is determined. Can be RB
# missing is determined. Can be VBG
# family is determined. Can be NN
# #family is determined. Can be RB
# blackbarbie is determined. Can be NN
# 027 is determined. Can be CD
# entire is determined. Can be JJ
# college is determined. Can be NN
# lost is ambiguous Can be VBD,VBN
# transcript is determined. Can be NN
# cant is ambiguous Can be NN,JJ
# attend is determined. Can be VBP
# summer is determined. Can be NN
# catch is determined. Can be NN
# w is ambiguous Can be NN,VBP
# / is ambiguous Can be NNP,NNS,VBP,$,JJ,NN
# kindle is ambiguous Can be NN,VBD,VB,$,JJ
# 2 is determined. Can be CD
# stacks is determined. Can be NNS
# books is determined. Can be NNS
# trip is determined. Can be NN
# way is determined. Can be NN
# look is ambiguous Can be NN,VB,VBP
# available is determined. Can be JJ
# amazon is ambiguous Can be NN,IN
# dx is determined. Can be JJ
# http://shortto/87ub is determined. Can be NN
# top is determined. Can be JJ
# electronic is determined. Can be JJ
# reader is determined. Can be NN
# period is determined. Can be NN
# day is determined. Can be NN
# warner is ambiguous Can be RBR,NN,WRB
# pulls is determined. Can be NNS
# plug is determined. Can be JJ
# girlfriend is determined. Can be VBP
# experience is determined. Can be NN
# wwwtinyurlcom is determined. Can be NN
# leavin is determined. Can be NN
# shauns is determined. Can be NNS
# grandparents is determined. Can be NNS
# around is determined. Can be IN
# slow is determined. Can be JJ
# text is determined. Can be NN
# tweet is determined. Can be NN
# ariannagrace is determined. Can be NN
# 321 is determined. Can be CD
# stopped is determined. Can be VBD
# already is determined. Can be RB
# theyre is determined. Can be NN
# waiting is determined. Can be VBG
# government is determined. Can be NN
# software is determined. Can be NN
# ruby_gem is determined. Can be NN
# primary is determined. Can be JJ
# debit is determined. Can be NN
# card is determined. Can be NN
# visa is determined. Can be NN
# post is determined. Can be NN
# blog is determined. Can be NN
# cases is determined. Can be NNS
# #slc is determined. Can be NN
# #citycreek is determined. Can be JJ
# #apple is determined. Can be NN
# #applestore is determined. Can be RB
# #red is determined. Can be VBD
# #pr is determined. Can be NNP
# petewentz is determined. Can be NN
# wish is ambiguous Can be JJ,NN
# houston is determined. Can be NN
# shawn is determined. Can be NN
# connery is determined. Can be NN
# peirce is determined. Can be NN
# bronson is determined. Can be NN
# timothy is determined. Can be JJ
# dalton is determined. Can be NN
# roger is determined. Can be NN
# moore is determined. Can be NN
# city is determined. Can be NN
# soo is determined. Can be VBD
# happy is determined. Can be JJ
# home is determined. Can be NN
# school is determined. Can be NN
# foxnews is determined. Can be NNS
# pelosi is determined. Can be VBP
# stay is determined. Can be JJ
# china is ambiguous Can be RB,NN
# never is determined. Can be RB
# come is ambiguous Can be VBN,JJ,VBP
# warners is determined. Can be NNS
# hd is determined. Can be VBP
# line is determined. Can be NN
# lhawthorn is determined. Can be JJ
# coincidence is determined. Can be NN
# stalking is determined. Can be VBG
# twitter is ambiguous Can be JJR,NN,VBP,JJ
# feed is ambiguous Can be NN,VBP
# gsoc is determined. Can be JJ
# news is determined. Can be NN
# ; is determined. Can be :
# dommm is determined. Can be NN
# comcast is determined. Can be NN
# warp is determined. Can be NN
# aussie is determined. Can be NN
# cattle is determined. Can be NNS
# dog is determined. Can be VBP
# knightowl is determined. Can be NN
# 89 is determined. Can be CD
# sounds is ambiguous Can be NNS,VBZ
# done is determined. Can be VBN
# determined is determined. Can be VBN
# find is ambiguous Can be VBP,VB
# park is determined. Can be JJ
# go is ambiguous Can be VBP,VB,RB
# ahead is determined. Can be RB
# live is determined. Can be JJ
# premium is ambiguous Can be NN,JJ
# cabins is determined. Can be NNS
# heaven is determined. Can be RB
# en is determined. Can be IN
# route is determined. Can be NN
# internet is determined. Can be NN
# damn is determined. Can be NN
# take is ambiguous Can be VB,VBP
# steering is determined. Can be VBG
# wheel is ambiguous Can be VB,NN
# away is determined. Can be RB
# cold is determined. Can be JJ
# dead is determined. Can be JJ
# hands is determined. Can be NNS
# buy is ambiguous Can be VBP,VB
# using is determined. Can be VBG
# linux is determined. Can be JJ
# loving is determined. Can be VBG
# much is ambiguous Can be JJ,RB
# nicer is determined. Can be NN
# windows is determined. Can be VBZ
# looking is determined. Can be VBG
# forward is determined. Can be RB
# wysiwyg is determined. Can be JJ
# latex is ambiguous Can be NN,JJ
# asthma is determined. Can be NN
# blows is ambiguous Can be NNS,VBZ
# wait is ambiguous Can be NN,VBP
# till is ambiguous Can be NN,JJ
# finish is determined. Can be JJ
# asmanex is determined. Can be NN
# treatments is determined. Can be NNS
# follow is ambiguous Can be VBP,VB
# hopefully is determined. Can be RB
# final is determined. Can be JJ
# apt is determined. Can be NN
# pulmonologist is determined. Can be NN
# click is determined. Can be NN
# link is determined. Can be NN
# wants is determined. Can be VBZ
# info is determined. Can be NN
# havent is determined. Can be NN
# booked is determined. Can be VBD
# yet is determined. Can be RB
# read is ambiguous Can be VBN,NN,VBD
# waive is determined. Can be JJ
# fees is determined. Can be NNS
# military is determined. Can be JJ
# watching is determined. Can be VBG
# lebron is determined. Can be NN
# highlights is determined. Can be NNS
# niggas is determined. Can be RB
# dell is determined. Can be NN
# laptops is determined. Can be VBZ
# battery is determined. Can be NN
# thanks is determined. Can be NNS
# reupgrade is determined. Can be VBD
# 1st is determined. Can be CD
# class is determined. Can be NN
# may is determined. Can be MD
# 45 is determined. Can be CD
# min is determined. Can be NN
# hearing is determined. Can be VBG
# coming is determined. Can be VBG
# da is determined. Can be JJ
# people is determined. Can be NNS
# lazy is determined. Can be VBP
# seems is determined. Can be VBZ
# dangerous is determined. Can be JJ
# jessicarayburn is determined. Can be NN
# accidentally is determined. Can be RB
# stepped is determined. Can be VBD
# power is determined. Can be NN
# strip is determined. Can be NN
# button is determined. Can be NN
# internets is determined. Can be NNS
# fucked is ambiguous Can be VBD,VBN
# sent is determined. Can be JJ
# message is ambiguous Can be NN,VB
# let is ambiguous Can be NN,VB
# know is ambiguous Can be VB,NN,VBP
# reading is ambiguous Can be VBG,NN
# lee is determined. Can be NN
# childs is determined. Can be NNS
# video is determined. Can be NN
# first is ambiguous Can be RB,JJ
# user is determined. Can be RB
# 95 is determined. Can be CD
# % is determined. Can be NN
# vision is determined. Can be NN
# well is determined. Can be RB
# past is determined. Can be IN
# legally is determined. Can be RB
# blind is determined. Can be VB
# http://tco/wk6qeqif is determined. Can be NN
# 12 is determined. Can be CD
# hours is determined. Can be NNS
# joke is determined. Can be NN
# went is determined. Can be VBD
# santa is determined. Can be JJ
# cruz is determined. Can be NN
# 30 is determined. Can be CD
# mins is determined. Can be NNS
# hella is determined. Can be NN
# old is determined. Can be JJ
# cocacola is determined. Can be NN
# guy is ambiguous Can be NN,JJ
# gm is ambiguous Can be FW,JJ,NN,RB,VB
# board is determined. Can be NN
# stupid is determined. Can be JJ
# heck is determined. Can be NN
# #tcot is determined. Can be NNP
# jakes is determined. Can be NNS
# going is determined. Can be VBG
# jonathanrknight is determined. Can be NN
# hear is ambiguous Can be VBP,JJ
# rock is determined. Can be NN
# hope is ambiguous Can be NN,VBP
# tonight is ambiguous Can be VBD,NN
# many is determined. Can be JJ
# feel is ambiguous Can be NN,VBP
# outsourcing is determined. Can be VBG
# plan is determined. Can be NN
# boise is determined. Can be RB
# best is ambiguous Can be JJS,RBS
# staff is determined. Can be NN
# cust is determined. Can be NN
# service is determined. Can be NN
# send is determined. Can be VB
# chevy is determined. Can be NN
# photos is determined. Can be NNS
# saw is ambiguous Can be VBD,NN
# loved is determined. Can be VBD
# see is ambiguous Can be VBP,NN,VB
# lyx is determined. Can be NN
# cox is ambiguous Can be NN,VBP
# cheaper is determined. Can be JJR
# gets is determined. Can be VBZ
# b is ambiguous Can be JJR,NN
# dslreports is determined. Can be NNS
# tw is determined. Can be RBR
# expensive is determined. Can be JJ
# god is ambiguous Can be JJ,NN
# stomach is determined. Can be NN
# mean is determined. Can be JJ
# notre is determined. Can be NN
# dame is determined. Can be NN
# id is ambiguous Can be NNS,NN
# closer is determined. Can be RBR
# dan is determined. Can be NN
# booz is determined. Can be JJ
# allen is determined. Can be VBN
# hamilton is determined. Can be NN
# 2hr is determined. Can be CD
# meeting is determined. Can be NN
# fastcodesign is determined. Can be NN
# excited is ambiguous Can be VBD,JJ
# taking is determined. Can be VBG
# katie is determined. Can be JJ
# church is determined. Can be NN
# totally is determined. Can be RB
# hate is ambiguous Can be JJ,NN,VB
# obama is determined. Can be NN
# popular is determined. Can be JJ
# among is determined. Can be IN
# arabs is determined. Can be NNS
# survey is determined. Can be NN
# president is determined. Can be NN
# barack is determined. Can be NN
# obamas is determined. Can be NN
# popularity is determined. Can be NN
# leading is determined. Can be VBG
# arab is determined. Can be JJ
# countries is determined. Can be NNS
# test is determined. Can be NN
# steve is determined. Can be NN
# mahan is determined. Can be NN
# amazing is ambiguous Can be VBG,NN
# #google is determined. Can be NN
# sb is ambiguous Can be JJ,VBP
# blazer is determined. Can be NN
# high is determined. Can be JJ
# acg is determined. Can be NN
# custom is determined. Can be NN
# brad is determined. Can be NN
# douglas is determined. Can be NNS
# anymore is determined. Can be RB
# stinky is determined. Can be JJ
# mail is determined. Can be NN
# order is determined. Can be NN
# bride is determined. Can be IN
# pissing is determined. Can be VBG
# saved is determined. Can be VBN
# opting is determined. Can be VBG
# grocery is determined. Can be NN
# store is determined. Can be NN
# stocking is determined. Can be VBG
# hotel is determined. Can be NN
# room is determined. Can be NN
# fridge is determined. Can be NN
# vs is determined. Can be NN
# eating is determined. Can be VBG
# every is determined. Can be DT
# sportsguy is ambiguous Can be NN,VBD
# 33 is determined. Can be CD
# ummm is determined. Can be JJ
# someday is determined. Can be JJ
# nearly is determined. Can be RB
# acutally is determined. Can be RB
# freeway is determined. Can be RB
# 880 is determined. Can be CD
# north is determined. Can be JJ
# broke is determined. Can be VBD
# flights is determined. Can be NNS
# 1970 1366 is determined. Can be CD
# 1552 is determined. Can be CD
# fly is determined. Can be NN
# 1 is determined. Can be CD
# mind is determined. Can be NN
# ocean is determined. Can be JJ
# approach is determined. Can be NN
# zydrunas is determined. Can be CD
# awesome is determined. Can be JJ
# total is determined. Can be JJ
# believe is determined. Can be VBP
# mashable is ambiguous Can be JJ,NN
# safer is determined. Can be NN
# average is determined. Can be NN
# driver is determined. Can be NN
# outside is determined. Can be IN
# barnwell is determined. Can be NN
# #alberta is determined. Can be NNP
# #taber is determined. Can be NNP
# half is ambiguous Can be JJ,NN
# east is ambiguous Can be NN,JJ
# arg is determined. Can be RB
# api is ambiguous Can be NN,JJ
# making is determined. Can be VBG
# ask is ambiguous Can be NN,VBD
# programming is determined. Can be NN
# indesign is determined. Can be NN
# submitted is determined. Can be VBN
# calcio is determined. Can be NN
# [ is ambiguous Can be NN,VBD
# ] is ambiguous Can be NNP,NN
# comment is determined. Can be NN
# shaunwoo is determined. Can be NN
# haten is determined. Can be NNS
# five is determined. Can be CD
# things is determined. Can be NNS
# wolfram is determined. Can be VBP
# alpha is determined. Can be RB
# vastly is determined. Can be RB
# different is determined. Can be JJ
# cwong is determined. Can be RB
# 08 is determined. Can be CD
# sony is ambiguous Can be JJ,NN
# prs is determined. Can be NN
# 500 is determined. Can be CD
# physical is determined. Can be JJ
# device is determined. Can be NN
# feels is determined. Can be NNS
# font is determined. Can be JJ
# nice is ambiguous Can be JJ,RB,VB
# pg is determined. Can be NN
# turns is determined. Can be VBZ
# snappy is determined. Can be JJ
# enuf is determined. Can be NN
# ui is determined. Can be JJ
# little is determined. Can be JJ
# jenniferdaniel is determined. Can be NN
# someone is determined. Can be NN
# learned is determined. Can be VBD
# drive is ambiguous Can be JJ,NN
# welcome is determined. Can be NN
# blow is determined. Can be JJ
# korea is determined. Can be JJ
# map is determined. Can be NN
# took is determined. Can be VBD
# graduate is determined. Can be NN
# field is determined. Can be NN
# computer is determined. Can be NN
# science is determined. Can be NN
# makes is determined. Can be VBZ
# idiot is determined. Can be NN
# lambda is ambiguous Can be NN,JJ
# imagine is determined. Can be JJ
# world is determined. Can be NN
# merges is determined. Can be NNS
# #itscoming is determined. Can be VBG
# œ is determined. Can be NN
# di is determined. Can be NN
# caro is determined. Can be NN
# uses is determined. Can be VBZ
# last is determined. Can be JJ
# question is determined. Can be NN
# #mocotranspo is determined. Can be VBP
#  is ambiguous Can be JJ,NN
# wild is determined. Can be JJ
# checking is determined. Can be NN
# jktweet is determined. Can be NN
# hi is ambiguous Can be NN,JJ
# stanford is determined. Can be JJ
# liked is determined. Can be JJ
# advice is determined. Can be NN
# saying is determined. Can be VBG
# singapore is determined. Can be RB
# yes is ambiguous Can be NNS,VBP
# videos is determined. Can be VBP
# revision is determined. Can be NN
# boring is determined. Can be VBG
# unprepared is determined. Can be JJ
# tomorrow is determined. Can be NN
# imessage is determined. Can be VB
# doesnt is ambiguous Can be JJ,VBD
# work is ambiguous Can be NN,VBD
# recovering is determined. Can be VBG
# surgerywishing is determined. Can be VBG
# julesrenner is determined. Can be NN
# asherroth is determined. Can be DT
# cup is determined. Can be NN
# 2010 is determined. Can be CD
# access is determined. Can be NN
# switched is determined. Can be VBD
# delta is determined. Can be NN
# two is determined. Can be CD
# trips is determined. Can be NNS
# disappointed is determined. Can be VBD
# ua4646 is determined. Can be JJ
# 2/23 is determined. Can be CD
# delayed is determined. Can be VBD
# 3 is determined. Can be CD
# playing is determined. Can be VBG
# java is determined. Can be NN
# pet is determined. Can be JJ
# http://xigs/04fo is determined. Can be NN
# ceo is determined. Can be NN
# continue is determined. Can be VBP
# key is determined. Can be JJ
# admit is determined. Can be NN
# youve is ambiguous Can be NN,VBP
# rather is determined. Can be RB
# years is determined. Can be NNS
# still is determined. Can be RB
# hooked is determined. Can be JJ
# dorkas is determined. Can be NN
# 426 is determined. Can be CD
# change is determined. Can be NN
# scenery is determined. Can be NN
# timely is determined. Can be RB
# getting is determined. Can be VBG
# wife is determined. Can be NN
# cancun is determined. Can be NN
# appreciate is determined. Can be NN
# flyana_official is determined. Can be NN
# pleasantly is determined. Can be RB
# surprised is determined. Can be VBD
# ana is determined. Can be NN
# major is determined. Can be JJ
# upgrades is determined. Can be NNS
# transpacific is determined. Can be IN
# karrisfoxy is determined. Can be JJ
# harassed is determined. Can be VBD
# calls is determined. Can be NNS
# warranty is determined. Can be NN
# changing is determined. Can be VBG
# number is determined. Can be NN
# wont is ambiguous Can be JJ,NN
# fix is ambiguous Can be NN,JJ
# call is determined. Can be NN
# fucken is determined. Can be JJ
# man is determined. Can be NN
# lol is ambiguous Can be NN,VBP,JJ
# tiring is determined. Can be VBG
# job is determined. Can be NN
# bout is determined. Can be RB
# hills is determined. Can be NNS
# dang is determined. Can be VBP
# nabbit is determined. Can be RB
# fish is determined. Can be JJ
# u is ambiguous Can be JJ,NNS
# teach is determined. Can be VB
# life is determined. Can be NN
# f is ambiguous Can be NN,JJ
# * is determined. Can be NNP
# k is determined. Can be VBD
# wave is determined. Can be VBP
# developer is determined. Can be NN
# sandbox is determined. Can be NN
# account is determined. Can be NN
# request is determined. Can be NN
# vkerkez is determined. Can be NN
# dood is determined. Can be NN
# android is determined. Can be NN
# conference is determined. Can be NN
# sunshine is determined. Can be NN
# cleaning is determined. Can be VBG
# amy is determined. Can be JJ
# ugh is ambiguous Can be JJ,IN
# need is ambiguous Can be MD,VBP
# renew is determined. Can be VB
# restraining is determined. Can be VBG
# tweeterdiva is determined. Can be NN
# herd is determined. Can be NN
# anna_debenham is determined. Can be NN
# php is determined. Can be NN
# bank is determined. Can be NN
# holiday is ambiguous Can be NN,JJ
# season is determined. Can be NN
# sucks is determined. Can be NNS
# charlesjmeyer is determined. Can be NN
# apple is determined. Can be NN
# appy_geek is determined. Can be JJ
# hasnt is determined. Can be NN
# decades is determined. Can be NNS
# support is ambiguous Can be NN,VBP
# bonjour is determined. Can be JJ
# san is ambiguous Can be NN,JJ
# francisco is determined. Can be NN
# hurts is determined. Can be VBZ
# drove is determined. Can be VBD
# pittstock is determined. Can be RB
# $ is determined. Can be $
# riddance is determined. Can be NN
# sad is determined. Can be JJ
# didnt is determined. Can be NN
# expect is determined. Can be VBP
# radio is determined. Can be NN
# morning is determined. Can be NN
# discussing is determined. Can be VBG
# #coachella2015 is determined. Can be JJ
# lineup is determined. Can be NN
# thx is determined. Can be NN
# golf is determined. Can be NN
# carts is determined. Can be NNS
# star is ambiguous Can be NN,JJ
# trek is ambiguous Can be NN,NNS
# everyone is determined. Can be NN
# guess is determined. Can be NN
# ill is ambiguous Can be NN,RB
# retiring is determined. Can be VBG
# g1 is determined. Can be JJ
# start is determined. Can be NN
# woot is determined. Can be NN
# upside is determined. Can be JJ
# unhelpful is determined. Can be JJ
# operators is determined. Can be NNS
# superslow is determined. Can be VBP
# onsite is determined. Can be JJ
# crap is determined. Can be NN
# highly is determined. Can be RB
# recommend is determined. Can be NN
# http://tinyurlcom/howdavidbeatsgoliath is determined. Can be NN
# malcolm is determined. Can be NN
# dwight is determined. Can be NN
# howards is determined. Can be NNS
# vitamin is determined. Can be VBP
# water is determined. Can be NN
# commercial is determined. Can be JJ
# adidas is determined. Can be NNS
# shows is determined. Can be VBZ
# funny is determined. Can be JJ
# side is determined. Can be NN
# > is ambiguous Can be NNP,NN
# speed is determined. Can be NN
# batman is determined. Can be NN
# speeds is determined. Can be NNS
# club is determined. Can be NN
# iad is determined. Can be NN
# insanely is determined. Can be RB
# fast is ambiguous Can be JJ,NN
# automated is determined. Can be VBD
# waste is ambiguous Can be VB,VBP
# protected is determined. Can be VBD
# gate is determined. Can be NN
# agent is determined. Can be NN
# kerry is determined. Can be NNP
# las is determined. Can be VBZ
# also is determined. Can be RB
# excellent is determined. Can be JJ
# destination is determined. Can be NN
# found is ambiguous Can be JJ,VBN,VBD
# clothes is determined. Can be NNS
# em is determined. Can be NN
# d3signerd is determined. Can be NN
# ¦ is determined. Can be NNP
# systematically is determined. Can be RB
# run is determined. Can be VBP
# york is determined. Can be NN
# natural is determined. Can be JJ
# miss is ambiguous Can be NNS,NN
# bloomingdale is determined. Can be NN
# unfortunate is determined. Can be JJ
# stimulus is determined. Can be NN
# put is determined. Can be VBD
# place is determined. Can be NN
# twice is determined. Can be RB
# help is determined. Can be NN
# american is determined. Can be JJ
# led is determined. Can be VBD
# futuristic is determined. Can be JJ
# stuff is determined. Can be NN
# giving is determined. Can be VBG
# face is determined. Can be NN
# pretty is determined. Can be RB
# genius is determined. Can be NN
# blown is determined. Can be VBN
# stellar is determined. Can be JJ
# #custserv is determined. Can be NNP
# thank is ambiguous Can be NN,VBD
# terrible is determined. Can be JJ
# anyone is determined. Can be NN
# fan is determined. Can be NN
# argh is determined. Can be NN
# testing is determined. Can be VBG
# acceptable is determined. Can be JJ
# level is determined. Can be NN
# risk is determined. Can be NN
# technology is determined. Can be NN
# reality is determined. Can be NN
# die is determined. Can be VBP
# autonomous is determined. Can be JJ
# hard is determined. Can be JJ
# accept is determined. Can be NN
# listening is determined. Can be VBG
# pyt is determined. Can be NN
# danny is determined. Can be NN
# gokey is determined. Can be NN
# aww is determined. Can be NN
# hes is determined. Can be NNS
# helpbeen is determined. Can be NN
# ua3426 is determined. Can be NN
# 2/19 is determined. Can be CD
# stretching is determined. Can be VBG
# midnight is determined. Can be NN
# extremely is determined. Can be RB
# chicagos is determined. Can be NN
# hometown is determined. Can be JJ
# airline is determined. Can be NN
# care is determined. Can be NN
# neighbors is determined. Can be NNS
# #savethediagonals is determined. Can be VBP
# #flyquiet is determined. Can be JJ
# effing is determined. Can be VBG
# pissed is determined. Can be VBN
# midcontract is determined. Can be NN
# upgrade is determined. Can be JJ
# price is determined. Can be NN
# iphone is ambiguous Can be RB,NN
# 200 is determined. Can be CD
# pay is determined. Can be VB
# 499 is determined. Can be CD
# thought is ambiguous Can be VBD,VBN,NN
# safeway is ambiguous Can be RB,NN
# supermarketing is determined. Can be VBG
# via is determined. Can be IN
# mobile is determined. Can be JJ
# coupons is determined. Can be NNS
# think is ambiguous Can be NN,VB,VBP
# dislike is determined. Can be VBP
# buses is determined. Can be NNS
# glasses is determined. Can be NNS
# causes is ambiguous Can be NNS,VBZ
# children is determined. Can be NNS
# curses is determined. Can be NNS
# universewx is determined. Can be JJ
# heard is determined. Can be NN
# florida is determined. Can be NN
# streetlegal is determined. Can be JJ
# itchy is determined. Can be NN
# trainer is determined. Can be NN
# dunk is determined. Can be NN
# low is determined. Can be JJ
# white is determined. Can be JJ
# gum is determined. Can be NN
# early is determined. Can be JJ
# crabby is determined. Can be NN
# bed is ambiguous Can be VBN,VBD
# pup is determined. Can be NN
# staying is determined. Can be VBG
# 4 is determined. Can be CD
# phyreman is determined. Can be NN
# 9 is determined. Can be CD
# always is determined. Can be RB
# shouldve is determined. Can be NN
# mentioned is determined. Can be VBD
# mustang is determined. Can be JJ
# dad is ambiguous Can be VBZ,JJ
# hungry is determined. Can be JJ
# applied is determined. Can be VBN
# seeing is determined. Can be VBG
# ambcharlesfield is determined. Can be NN
# ah is determined. Can be NN
# skin is determined. Can be JJ
# mmcallen is determined. Can be VBN
# sigh is determined. Can be JJ
# gmic is determined. Can be VB
# diego is determined. Can be NN
# spoke is determined. Can be VBD
# johanna is determined. Can be NN
# said is determined. Can be VBD
# barraged is determined. Can be VBN
# horde is determined. Can be NN
# insects is determined. Can be NNS
# kitchen is determined. Can be NN
# light is determined. Can be VBD
# headline is determined. Can be NN
# usatoday is determined. Can be NN
# california is determined. Can be NN
# okays is determined. Can be VBZ
# maybe is determined. Can be RB
# dance is determined. Can be NN
# steps is determined. Can be NNS
# use is ambiguous Can be VBP,VB
# todays is determined. Can be NNS
# #patriots is determined. Can be NNS
# craigsutton is determined. Can be NN
# longtime is determined. Can be RB
# furkin is determined. Can be JJ
# ericbttn is determined. Can be NN
# right is determined. Can be RB
# hang is determined. Can be VBD
# cast is determined. Can be VBN
# alex is determined. Can be JJ
# fall is determined. Can be NN
# bill is determined. Can be NN
# clinton is determined. Can be NN
# fail is ambiguous Can be VBP,JJ
# win is determined. Can be NN
# yung is determined. Can be NN
# adopted is determined. Can be VBD
# child is determined. Can be JJ
# namin is determined. Can be JJ
# bitten is ambiguous Can be JJ,VBP
# wasp is determined. Can be NN
# gave is determined. Can be VBD
# plans is determined. Can be NNS
# build is determined. Can be VBP
# arzekjjr is determined. Can be VBZ
# 4q is determined. Can be CD
# dear is determined. Can be JJ
# worse is determined. Can be NN
# ever is determined. Can be RB
# real is determined. Can be JJ
# moment is determined. Can be NN
# missssssssss is determined. Can be NN
# math is determined. Can be NN
# aiduong is determined. Can be RB
# goodness is determined. Can be NN
# friends is determined. Can be NNS
# hello is determined. Can be JJ
# liltanlines is determined. Can be NNS
# special is determined. Can be JJ
# hahaha is determined. Can be NN
# olympics is determined. Can be NNS
# compete is determined. Can be JJ
# arriving is determined. Can be VBG
# late is ambiguous Can be JJ,RB
# flightr is determined. Can be NN
# supposed is determined. Can be VBD
# lesson is determined. Can be JJ
# verbal is determined. Can be JJ
# written is determined. Can be VBN
# confirmations is determined. Can be NNS
# wonder is determined. Can be NN
# ’ is ambiguous Can be NN,NNP
# investigation is determined. Can be NN
# determine is determined. Can be NN
# inflated is determined. Can be VBN
# heads is determined. Can be NNS
# myspace is determined. Can be NN
# check is determined. Can be VB
# comments is determined. Can be NNS
# ready is determined. Can be JJ
# watch is ambiguous Can be JJ,NN
# dum is determined. Can be NN
# sho is determined. Can be VBZ
# blessed is determined. Can be VBN
# + is ambiguous Can be NN,NNP
# discovered is determined. Can be VBN
# easter is ambiguous Can be RBR,NN
# crafts is determined. Can be NNS
# eggs is determined. Can be NNS
# hot is determined. Can be JJ
# buns is determined. Can be NNS
# prince is determined. Can be NN
# egypt is determined. Can be NN
# aid is determined. Can be NN
# bobby is determined. Can be NN
# flay is determined. Can be NN
# fieri is determined. Can be NN
# music is determined. Can be NN
# couldnt is determined. Can be NN
# reaaly is determined. Can be NN
# john is determined. Can be NN
# mayers is determined. Can be NNS
# twitters is determined. Can be NNS
# rude is determined. Can be JJ
# remove is determined. Can be VBP
# tweets is determined. Can be NNS
# calculus is determined. Can be NN
# uploading is determined. Can be VBG
# greatest is determined. Can be JJS
# cartoon is determined. Can be NN
# newspaper is determined. Can be NN
# regarding is determined. Can be VBG
# riding is determined. Can be VBG
# œalways_believin is determined. Can be NN
# mazy is determined. Can be JJ
# 10 is determined. Can be CD
# #askmazy is determined. Can be NN
# balls is determined. Can be NNS
# #tombrady is determined. Can be NN
# tell is ambiguous Can be NN,VB
# programs is determined. Can be NNS
# arhh is determined. Can be NN
# weka is determined. Can be NN
# bug is determined. Can be NN
# spent is determined. Can be VBD
# almost is determined. Can be RB
# myfoxdc is determined. Can be NN
# barrie is determined. Can be NN
# students is determined. Can be NNS
# silver is determined. Can be NN
# spring is determined. Can be NN
# schools is determined. Can be NNS
# #wearabledevices is determined. Can be NNS
# #consumers is determined. Can be NNS
# putting is determined. Can be VBG
# 2essgn5wsv is determined. Can be CD
# #ibdnews is determined. Can be NNS
# #aapl is ambiguous Can be NNP,JJ
# #nke is determined. Can be NNP
# #grmn is determined. Can be NNP
# #amba is determined. Can be NNP
# gerry_butler is determined. Can be NN
# enjoy is determined. Can be RB
# make is ambiguous Can be VB,JJ
# wsj is determined. Can be NN
# would is determined. Can be MD
# ride is determined. Can be VB
# #tolazytodrive is determined. Can be CD
# freaking is determined. Can be VBG
# assignments is determined. Can be NNS
# jokes is determined. Can be NNS
# haha is determined. Can be JJ
# bit is determined. Can be NN
# dinner is determined. Can be NN
# speech is determined. Can be NN
# mr is determined. Can be NN
# lovin is determined. Can be NN
# running is determined. Can be VBG
# spot is determined. Can be NN
# normal is determined. Can be JJ
# weight is determined. Can be VBD
# big is determined. Can be JJ
# mischaarmada is determined. Can be NN
# girl is determined. Can be VBP
# walked is determined. Can be VBN
# bean is determined. Can be JJ
# yelled is determined. Can be VBN
# miiiiisssccchhhhhhh is determined. Can be NN
# amount is determined. Can be NN
# memory is determined. Can be NN
# least is determined. Can be JJS
# dslr is determined. Can be NN
# ahh is determined. Can be JJ
# ima is determined. Can be RB
# hubby is determined. Can be NN
# sum is determined. Can be JJ
# mcdonalds is determined. Can be NNS
# lou is determined. Can be RB
# 911 is determined. Can be CD
# murdering is determined. Can be NN
# air is determined. Can be NN
# yeezy is determined. Can be NNS
# khaki is determined. Can be VBP
# pink is determined. Can be VBP
# colorway is determined. Can be JJ
# release is determined. Can be NN
# picking is determined. Can be VBG
# streets is determined. Can be NNS
# http://tco/6f8qfwzbqg is determined. Can be VBP
# cannot is ambiguous Can be JJ,NN
# mountain is determined. Can be NN
# view is determined. Can be NN
# prius is determined. Can be JJ
# large is determined. Can be JJ
# roof is determined. Can be NN
# rack is determined. Can be NN
# questions is determined. Can be NNS
# disney is determined. Can be NN
# april is determined. Can be NN
# please is ambiguous Can be NN,JJ
# dm is determined. Can be VB
# eekkk is determined. Can be JJ
# adobe is determined. Can be NN
# cs4 is determined. Can be VBZ
# goodby is determined. Can be NN
# silverstein is determined. Can be NN
# guys is determined. Can be NNS
# safest is determined. Can be JJS
# #cas13 is determined. Can be VBP
# delivering is determined. Can be VBG
# packages is determined. Can be NNS
# humanoid is determined. Can be JJ
# robots is determined. Can be NNS
# happen is determined. Can be VBP
# drone is determined. Can be NN
# bs is determined. Can be NN
# defsounds is determined. Can be NNS
# wtf is determined. Can be VBP
# point is determined. Can be NN
# deleting is determined. Can be VBG
# summize is determined. Can be JJ
# searches is determined. Can be NNS
# wrote is determined. Can be VBD
# story is determined. Can be NN
# save is determined. Can be VBP
# mrskutcher is determined. Can be RB
# 1am is determined. Can be CD
# hereim is determined. Can be JJ
# weird is determined. Can be JJ
# seem is determined. Can be VBP
# overhyped is determined. Can be VBD
# given is determined. Can be VBN
# infrastructure is determined. Can be NN
# challenges is determined. Can be VBZ
# doable is determined. Can be JJ
# track is determined. Can be NN
# iran is determined. Can be NN
# social is determined. Can be JJ
# media is determined. Can be NNS
# flaws is determined. Can be NNS
# http://tco/qgqe2joymd is determined. Can be VBP
# sharethis is determined. Can be NN
# #autonomous is determined. Can be JJ
# motor is determined. Can be NN
# vehicles is determined. Can be NNS
# vonster is determined. Can be RB
# draw is determined. Can be NN
# quote is determined. Can be NN
# runner is determined. Can be NN
# customer is determined. Can be NN
# highspeed is determined. Can be JJ
# net is determined. Can be NN
# options is determined. Can be NNS
# barrier_trio is determined. Can be NN
# piss is determined. Can be JJ
# ppl is determined. Can be NN
# comparing is determined. Can be VBG
# robber is determined. Can be NN
# barons is determined. Can be NNS
# throwing is determined. Can be VBG
# dollars is determined. Can be NNS
# office is determined. Can be NN
# told is determined. Can be RB
# sick is ambiguous Can be NN,JJ
# goes is determined. Can be VBZ
# claritin is determined. Can be NN
# training is determined. Can be VBG
# beta is determined. Can be NN
# app is determined. Can be NN
# select is determined. Can be NN
# green is determined. Can be JJ
# tea is determined. Can be NN
# icecream is determined. Can be NN
# bought is determined. Can be VBD
# cartons is determined. Can be NNS
# _ is determined. Can be NNP
# fantastic is determined. Can be JJ
# investmentbut is determined. Can be NN
# future is determined. Can be NN
# aapl is determined. Can be VBZ
# beat is determined. Can be JJ
# battles is determined. Can be VBZ
# appease is determined. Can be JJ
# passengers is determined. Can be NNS
# wall is determined. Can be VBP
# street is determined. Can be JJ
# waterbury is determined. Can be JJ
# republican is determined. Can be JJ
# judd is determined. Can be NN
# apatow is determined. Can be NN
# creates is determined. Can be NNS
# fake is determined. Can be VBP
# sitcom is determined. Can be JJ
# nbccom is determined. Can be NN
# market is determined. Can be NN
# movie is determined. Can be NN
# viral is determined. Can be JJ
# marketing is determined. Can be NN
# picks is determined. Can be VBZ
# worst is determined. Can be JJ
# mtvcom is determined. Can be JJ
# mayhemstudios is determined. Can be NNS
# friday is determined. Can be JJ
# keep is determined. Can be VB
# connection is determined. Can be NN
# ord is determined. Can be NN
# fwa is determined. Can be NN
# boards is determined. Can be NNS
# ten is determined. Can be VBP
# minutes is determined. Can be NNS
# open is determined. Can be JJ
# plane is determined. Can be NN
# landed is determined. Can be VBD
# hassox is determined. Can be JJ
# idea is determined. Can be NN
# burning is determined. Can be VBG
# cash is determined. Can be NN
# chrysler is determined. Can be NN
# financial is determined. Can be JJ
# tsunami is determined. Can be NN
# bailout is determined. Can be NN
# means is determined. Can be VBZ
# soon is determined. Can be RB
# safari is determined. Can be RB
# shitty is determined. Can be VBP
# flew is determined. Can be VBD
# miami is determined. Can be NN
# crew is determined. Can be NN
# legs is determined. Can be NNS
# beycah is determined. Can be RB
# becca is determined. Can be NN
# engine is determined. Can be NN
# interface is determined. Can be NN
# bird is determined. Can be NN
# strike is determined. Can be NN
# data is determined. Can be NNS
# tests is determined. Can be NNS
# logo is determined. Can be VBD
# lifes is determined. Can be JJ
# bitch is determined. Can be NN
# dick is determined. Can be NN
# cheney is determined. Can be NN
# #p2 is determined. Can be NNP
# #bipart is determined. Can be NNP
# #tlot is determined. Can be NNP
# #hhrs is determined. Can be NNP
# #gop is determined. Can be NNP
# #dnc is determined. Can be NNP
# heres is determined. Can be VBZ
# sihocde is determined. Can be VBZ
# yahoo is determined. Can be NN
# answers is determined. Can be NNS
# butt is determined. Can be VBP
# honestonly is determined. Can be RB
# surprise is determined. Can be NN
# arod is determined. Can be NN
# isnt is determined. Can be NN
# somehow is determined. Can be RB
# cease is determined. Can be NN
# douchebaggery is determined. Can be NN
# 8: is determined. Can be CD
# 28 is determined. Can be CD
# wrong is determined. Can be JJ
# dustyeyessem is determined. Can be NN
# agree is determined. Can be JJ
# bus is determined. Can be NN
# nick_carter is determined. Can be RB
# idol is determined. Can be JJ
# reply is determined. Can be NN
# evelynbyrne is determined. Can be JJ
# tried is determined. Can be VBD
# v is determined. Can be NN
# baseballamericacom is determined. Can be NN
# baseball is determined. Can be NN
# america is determined. Can be VBZ
# prospects is determined. Can be NNS
# ted is determined. Can be VBN
# wells is determined. Can be NNS
# theres is determined. Can be NNS
# steady is determined. Can be JJ
# #nfls is determined. Can be NNP
# investigations is determined. Can be NNS
# nott is determined. Can be RB
# later is determined. Can be RB
# erickoston is determined. Can be NN
# awful is determined. Can be JJ
# lot is determined. Can be NN
# nikes is determined. Can be NNS
# private is determined. Can be JJ
# jetsim is determined. Can be NN
# < is determined. Can be NN
# must is determined. Can be MD
# manual is determined. Can be VB
# override is determined. Can be IN
# type is determined. Can be NN
# programme is determined. Can be JJ
# hitler is determined. Can be NN
# enhancing is determined. Can be VBG
# geekiness is determined. Can be JJ
# cookcj is determined. Can be NN
# lovely is determined. Can be JJ
# mug is determined. Can be JJ
# wheres is determined. Can be NNS
# rest is determined. Can be JJS
# crazed is determined. Can be VBN
# drunk is determined. Can be JJ
# drivers is determined. Can be NNS
# society is determined. Can be NN
#  is determined. Can be NNP
# œœï is determined. Can be NNP
# ¸ is determined. Can be NNP
# œž is determined. Can be NNP
# « is determined. Can be NNP
# ‡ is determined. Can be NNP
# º is determined. Can be NNP
# sheer is determined. Can be NN
# desperation is determined. Can be NN
# funding is determined. Can be NN
# warren is ambiguous Can be NNS,JJ
# buffet is ambiguous Can be VBP,NN
# economy is determined. Can be NN
# ^ is determined. Can be VBP
# kp is determined. Can be JJ
# mention is determined. Can be NN
# quiche is determined. Can be NN
# breakfast is determined. Can be NN
# tandoori is determined. Can be NN
# chicken is ambiguous Can be NN,VBN
# entrees is determined. Can be VBZ
# accompaniments is determined. Can be NNS
# truly is determined. Can be RB
# #durham is determined. Can be NN
# crash is determined. Can be JJ
# nc is determined. Can be JJ
# injured is determined. Can be JJ
# http://tco/oz48xg2bx4 is determined. Can be JJ
# http://tco/sgdldh1pjf is determined. Can be NN
# #dur is determined. Can be NNP
# durhamnc is determined. Can be NN
# lounging is determined. Can be VBG
# taco is determined. Can be NN
# bell is determined. Can be NN
# ncis is determined. Can be JJ
# wrist is determined. Can be NN
# looked is determined. Can be VBD
# dr is determined. Can be NN
# scary is determined. Can be JJ
# places is determined. Can be NNS
# eagle is determined. Can be VBP
# eye is determined. Can be NN
# join is determined. Can be NN
# psyop is determined. Can be NN
# partners is determined. Can be NNS
# hp is determined. Can be VBP
# http://bitly/g2ru8 is determined. Can be NN
# play is determined. Can be NN
# hilarious is determined. Can be JJ
# lidelle is determined. Can be VBZ
# ahhgot is determined. Can be RB
# rid is determined. Can be JJ
# nap is determined. Can be JJ
# roomies is determined. Can be NNS
# cook is determined. Can be VBP
# end is determined. Can be NN
# monday is determined. Can be NN
# lakers is determined. Can be NNS
# played is determined. Can be VBD
# thursday is determined. Can be NN
# legalgeekery is determined. Can be NN
# yeahhhhhhhhh is determined. Can be NN
# wouldnt is determined. Can be VBP
# lived is determined. Can be VBN
# palo is determined. Can be NN
# alto is determined. Can be NN
# avoided is determined. Can be VB
# reps is determined. Can be NNS
# r is determined. Can be VBP
# dumber is determined. Can be VB
# nails is determined. Can be NNS
# working is determined. Can be VBG
# ago is determined. Can be RB
# markethappy is determined. Can be JJ
# stocks is determined. Can be NNS
# jon is determined. Can be NN
# cruise is determined. Can be JJ
# knight is determined. Can be VBN
# coupon is determined. Can be NN
# code is determined. Can be NN
# expires is determined. Can be VBZ
# owns is determined. Can be VBZ
# nba is determined. Can be JJ
# playoffs is determined. Can be NNS
# ads is determined. Can be NNS
# kobe is determined. Can be NN
# carmelo is determined. Can be NN
# http://owly/7uiy is determined. Can be NN
# #adidas is determined. Can be NNP
# #billups is determined. Can be NNP
# #howard is determined. Can be NNP
# #marketing is determined. Can be VBG
# shame is determined. Can be NN
# forced is determined. Can be VBD
# house is determined. Can be NN
# thinks is determined. Can be NNS
# sell is determined. Can be VBP
# boyfriend is determined. Can be NN
# shits is determined. Can be NNS
# hitting is determined. Can be VBG
# irancraziness is determined. Can be JJ
# indeed is determined. Can be RB
# worries is determined. Can be NNS
# chug is determined. Can be VBP
# mson is determined. Can be JJ
# ny is determined. Can be DT
# ate is determined. Can be VB
# mesa is determined. Can be NN
# grill is determined. Can be NN
# met is determined. Can be VBD
# fun is determined. Can be NN
# except is determined. Can be IN
# completely is determined. Can be RB
# voice is determined. Can be NN
# criticalpath is determined. Can be NN
# continual is determined. Can be JJ
# program is determined. Can be NN
# cheap is determined. Can be NN
# bing is determined. Can be NN
# stick is determined. Can be JJ
# ctesdahl is determined. Can be NN
# digg is determined. Can be VB
# stumbleboth is determined. Can be NN
# aided is determined. Can be VBN
# greatly is determined. Can be RB
# wasting is determined. Can be VBG
# countless is determined. Can be NN
# lunch is determined. Can be NN
# nuggetssss is determined. Can be NN
# investors is determined. Can be NNS
# weekend is determined. Can be NN
# oldie is determined. Can be NN
# goodie is determined. Can be NN

# %% [markdown]
# ## Frequency approach
# The first and simplest approaach to solfve word ambiguity is to assign the most "probable" label of the token to a word that can be ambiguous, for example if the word is in the ambiguous list lookout for lexicon higher probability. FIrst let's build a simple pre processor class:

# %%
class PreProcessor():
    
    def __init__(self, special_chars=''):
        self.special_chars = special_chars
    
    def process(self, string):
        return self.cleanString(string)
    
    def cleanString(self, string):
        clean_string = string.lower()
        cleaned_words = []
        for char in self.special_chars:
            clean_string = clean_string.replace(char, '')
            for word in clean_string.split(" "):
                clean_word = word.replace(" ", "")
                if len(clean_word) > 0 and clean_word not in cleaned_words:
                    cleaned_words.append(word.replace(" ", ""))
        return " ".join(cleaned_words)

# %% [markdown]
# Now let's see build a simple pos tagger class

# %%
class simplePOS():
    
    def __init__(self, lexicon, ambiguous, determined, pre_processor = None):
        self.lexicon = lexicon
        self.ambiguous = ambiguous
        self.determined = determined
        self.preProcessor = pre_processor if pre_processor else PreProcessor(",.@?!¬-\''=()")
        self.tokenizer = tokenizer = nltk.tokenize.TweetTokenizer()
    
    def pos_tag(self, string):
        tagged_tokens = []
        if self.preProcessor:
            string = self.preProcessor.process(string)
        tokens = self.tokenizer.tokenize(string)
        for t in tokens:
            print(t)
            #Classify the tokens
        return tagged_tokens

# %% [markdown]
# Instantiate the tag and assign a POS

# %%
pos_tagger = simplePOS(new_tweet_lexicon, ambiguous, determined)
print(pos_tagger.pos_tag("United nails stocks"))
# Out:
# [('united', 'JJ'), ('nails', 'NNS'), ('stocks', 'NNS')]

# %% [markdown]
# What will you do to, alter the probability according to the next tag?
#
# For each word consider the bigrams, fro example
# JJ NNS, will form a bigram, consider how many times a NNS is present after a JJ tag
# * Form all possible bigrams for JJ
# * Count how many bigrams start with JJ
# * Count how many bigrams starting with JJ are followed by a NNS, this will give you the probability of a transition
#
# **Exercise** given the list of tags and next_tags build the probability of a tag given another, the goal is to model the markovian state diagram
# Answer which is the probability to have a JJ tag given a NNS tag
